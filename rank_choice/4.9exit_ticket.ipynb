# %% [markdown]
# **4.9.Ranked Choice Voting Day 2**
#
# Create your own bar graph or pie chart about something personally important to you. Include a title and labels (for a pie chart) or categories (for the bar graph). Include a comment about why you chose this bar graph or pie chart.
#
# Screenshot your code and the resulting graph.

# %%
#inports
import matplotlib.pyplot as plt

# %%
labels = ["USACO Bronze", "USACO Silver", "CSES"]
frequency = [22,11,3]

plt.bar(labels,frequency)
plt.title("Number of Completed Coding Solutions")


plt.show()
